# %%
import pandas as pd
import numpy as np

# %%
# Load data
df = pd.read_csv("AAPL (4).csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     03-01-2012   58.485714   58.928570   58.428570   58.747143   50.765709
# 1     04-01-2012   58.571430   59.240002   58.468571   59.062859   51.038536
# 2     05-01-2012   59.278572   59.792858   58.952858   59.718571   51.605175
# 3     06-01-2012   59.967144   60.392857   59.888573   60.342857   52.144630
# 4     09-01-2012   60.785713   61.107143   60.192856   60.247143   52.061932
# ...          ...         ...         ...         ...         ...         ...
# 2006  23-12-2019  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007  24-12-2019  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008  26-12-2019  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009  27-12-2019  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010  30-12-2019  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 0     75555200
# ...

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2011.000000  2011.000000  2011.000000  2011.000000  2011.000000
# mean    126.707469   127.827594   125.580258   126.741235   119.505548
# std      50.483753    50.926301    50.124940    50.578369    52.438444
# min      55.424286    57.085712    55.014286    55.790001    48.921928
# 25%      85.882858    86.717858    85.056427    86.202145    75.056679
# 50%     113.050003   114.190002   111.870003   113.050003   105.222908
# 75%     165.190002   167.409996   163.424995   165.245002   160.047111
# max     291.119995   293.970001   288.119995   291.519989   289.522614
#
#              Volume
# count  2.011000e+03
# mean   5.949670e+07
# std    4.683856e+07
# min    1.136200e+07
# 25%    2.758565e+07
# 50%    4.346900e+07
# 75%    7.471030e+07
# max    3.765300e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2011 non-null   object
#  1   Open       2011 non-null   float64
#  2   High       2011 non-null   float64
#  3   Low        2011 non-null   float64
#  4   Close      2011 non-null   float64
#  5   Adj Close  2011 non-null   float64
#  6   Volume     2011 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 110.1+ KB

# %%
# Convert 'Date' to datetime and sort
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df = df.sort_values('Date').reset_index(drop=True)

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1    2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2    2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3    2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4    2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
#         Volume
# 0     75555200
# 1     65005500
# ...

# %%
# checking missing value
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# checking Duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Feature Engineering
#Moving Averages- Smooth out short-term noise and show price trends over time. Capture momentum or reversal signals (used in technical analysis). Helps ML models learn trend-based behavior (e.g., uptrend, downtrend).
#Volatility (Standard Deviation)- Measures how much the stock price fluctuates in a short period. Useful for predicting risk or sudden price swings. High volatility → Uncertainty; Low volatility → Stability
df['7_day_MA'] = df['Close'].rolling(window=7).mean()
df['14_day_MA'] = df['Close'].rolling(window=14).mean()
df['30_day_MA'] = df['Close'].rolling(window=30).mean()
df['Volatility_7'] = df['Close'].rolling(window=7).std()

# %%
# Lag features (previous close values)
#These features shift the target variable (Close) back in time so your model can learn from past behavior.
df['Close_lag1'] = df['Close'].shift(1) # yesterday's close
df['Close_lag2'] = df['Close'].shift(2) # day before yesterday

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2012-01-03   58.485714   58.928570   58.428570   58.747143   50.765709
# 1    2012-01-04   58.571430   59.240002   58.468571   59.062859   51.038536
# 2    2012-01-05   59.278572   59.792858   58.952858   59.718571   51.605175
# 3    2012-01-06   59.967144   60.392857   59.888573   60.342857   52.144630
# 4    2012-01-09   60.785713   61.107143   60.192856   60.247143   52.061932
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Open             0
# High             0
# Low              0
# Close            0
# Adj Close        0
# Volume           0
# 7_day_MA         6
# 14_day_MA       13
# 30_day_MA       29
# Volatility_7     6
# Close_lag1       1
# Close_lag2       2
# dtype: int64

# %%
# Drop NA rows created by rolling and shifting
df = df.dropna()

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 29   2012-02-14   72.094284   72.794289   71.714287   72.779999   62.892056
# 30   2012-02-15   73.465714   75.184288   70.984283   71.095711   61.436600
# 31   2012-02-16   70.214287   72.127144   69.518570   71.744286   61.997032
# 32   2012-02-17   71.872856   72.538574   71.471428   71.731430   61.985954
# 33   2012-02-21   72.411430   73.550003   72.017143   73.550003   63.557446
# ...         ...         ...         ...         ...         ...         ...
# 2006 2019-12-23  280.529999  284.250000  280.369995  284.000000  282.054138
# 2007 2019-12-24  284.690002  284.890015  282.920013  284.269989  282.322266
# 2008 2019-12-26  284.820007  289.980011  284.700012  289.910004  287.923645
# 2009 2019-12-27  291.119995  293.970001  288.119995  289.799988  287.814392
# 2010 2019-12-30  289.459991  292.690002  285.220001  291.519989  289.522614
#
# ...

# %% [markdown]
# **EDA – Trend, Seasonality, Volatility**

# %%
#Line Plot: Closing Price Over Time
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue')
plt.title('Apple Stock Closing Price (2012–2019)')
plt.xlabel('Date')
plt.ylabel('Close Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Moving Averages Overlay
plt.figure(figsize=(14,6))
plt.plot(df['Date'], df['Close'], label='Close Price', alpha=0.5)
plt.plot(df['Date'], df['30_day_MA'], label='30-Day MA', color='black')
plt.title('Apple Closing Price with 30-Day Moving Average')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Volatility Visualization (7-Day Rolling Std)
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Volatility_7'], color='red')
plt.title('7-Day Rolling Volatility of Apple Stock')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.grid(True)
plt.show()

# %%
# Monthly Average Price
df['Month'] = df['Date'].dt.to_period('M')
monthly_avg = df.groupby('Month')['Close'].mean()

plt.figure(figsize=(14,6))
monthly_avg.plot()
plt.title('Monthly Average Closing Price')
plt.xlabel('Month')
plt.ylabel('Average Close Price ($)')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-20-be500eeb1127>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Date'].dt.to_period('M')

# %%
# Seasonality Decomposition
#We’ll decompose the time series into trend, seasonal, and residual components.

from statsmodels.tsa.seasonal import seasonal_decompose

# Set date as index
df_decomp = df.set_index('Date')

# Resample to monthly average for clearer seasonality
monthly_close = df_decomp['Close'].resample('M').mean()

# Decompose the time series
decomposition = seasonal_decompose(monthly_close, model='additive', period=12)
decomposition.plot()
plt.suptitle('Seasonal Decomposition of Monthly Apple Stock Price', fontsize=16)
plt.tight_layout()
plt.show()

#Trend: Long-term movement
#Seasonal: Recurring patterns (monthly/quarterly)
#Residual: Noise
# Out:
# <ipython-input-21-344b5399f289>:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_close = df_decomp['Close'].resample('M').mean()

# %% [markdown]
# ## **Model Training**

# %%
# ARIMA Model (for time series trend)
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np

# Use only 'Close' for ARIMA
train = df_decomp['Close'][:-30]
test = df_decomp['Close'][-30:]

# Fit ARIMA model
model = ARIMA(train, order=(5,1,0))  # (p,d,q) can be tuned
model_fit = model.fit()

# Forecast next 30 days
forecast = model_fit.forecast(steps=30)

# Evaluation
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)
print(f"ARIMA RMSE: {rmse:.2f}")

# Plot forecast vs actual
plt.figure(figsize=(10,5))
plt.plot(test.index, test.values, label='Actual')
plt.plot(test.index, forecast, label='Forecast', linestyle='--')
plt.title('ARIMA Forecast vs Actual')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ...

# %%
# ARIMA Hyperparameter Tuning

import warnings
import itertools
from statsmodels.tsa.arima.model import ARIMA

p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))

best_score = float("inf")
best_cfg = None

for param in pdq:
    try:
        model = ARIMA(train, order=param)
        model_fit = model.fit()
        forecast = model_fit.forecast(steps=30)
        rmse = np.sqrt(mean_squared_error(test, forecast))
        if rmse < best_score:
            best_score = rmse
            best_cfg = param
        print(f'ARIMA{param} RMSE={rmse:.2f}')
    except:
        continue

print(f'\nBest ARIMA{best_cfg} RMSE={best_score:.2f}')
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ...

# %%
# XGBoost Model (with features)

from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split

# Features and target
features = ['Open', 'High', 'Low', 'Volume', '7_day_MA', '14_day_MA', '30_day_MA', 'Volatility_7', 'Close_lag1', 'Close_lag2']
target = 'Close'

# Remove rows with missing values (if any)
xgb_df = df.dropna()

X = xgb_df[features]
y = xgb_df[target]

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.1)

# Train model
xgb = XGBRegressor(n_estimators=100, learning_rate=0.1)
xgb.fit(X_train, y_train)

# Predict and evaluate
preds = xgb.predict(X_test)
rmse_xgb = np.sqrt(mean_squared_error(y_test, preds))
print(f"XGBoost RMSE: {rmse_xgb:.2f}")

# Plot
plt.figure(figsize=(10,5))
plt.plot(y_test.index, y_test.values, label='Actual')
plt.plot(y_test.index, preds, label='XGBoost Predictions', linestyle='--')
plt.title('XGBoost Forecast vs Actual')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# XGBoost RMSE: 19.12

# %%
# XGBoost Hyperparameter Tuning (GridSearchCV)

from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# Define parameter grid
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0]
}

# Setup GridSearchCV
xgb_model = XGBRegressor()
grid_search = GridSearchCV(estimator=xgb_model,
                           param_grid=param_grid,
                           scoring='neg_mean_squared_error',
                           cv=3,
                           verbose=1,
                           n_jobs=-1)

grid_search.fit(X_train, y_train)

# Best model
best_xgb = grid_search.best_estimator_
print("Best XGBoost Params:", grid_search.best_params_)

# Evaluate
xgb_preds = best_xgb.predict(X_test)
xgb_rmse = np.sqrt(mean_squared_error(y_test, xgb_preds))
print(f"Best XGBoost RMSE: {xgb_rmse:.2f}")
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# Best XGBoost Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0}
# Best XGBoost RMSE: 19.11

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit model
model = ARIMA(train, order=(2, 2, 1))
model_fit = model.fit()

# Forecast next 30 days
forecast = model_fit.forecast(steps=30)

# Evaluation
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)
print(f"ARIMA RMSE: {rmse:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA RMSE: 10.51
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# ...
